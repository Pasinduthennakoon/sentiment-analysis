# %% [markdown]
# ## import kaggle.json file data

# %%
import json
with open('../artifacts/kaggle.json', 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'pasinduthennakoon', 'key': '4ac9d7ee5b8e451e7d6f8f5373884786'}

# %% [markdown]
# ## install kaggle

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (1.8.2)
# Requirement already satisfied: black>=24.10.0 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from kaggle) (25.12.0)
# Requirement already satisfied: bleach in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: kagglesdk in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from kaggle) (0.1.13)
# Requirement already satisfied: mypy>=1.15.0 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from kaggle) (1.19.1)
# Requirement already satisfied: protobuf in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from kaggle) (6.33.2)
# Requirement already satisfied: python-dateutil in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: setuptools>=21.0.0 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from kaggle) (80.9.0)
# Requirement already satisfied: six>=1.10 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: tqdm in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: types-requests in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from kaggle) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from kaggle) (2.6.2)
# Requirement already satisfied: click>=8.0.0 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from black>=24.10.0->kaggle) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from black>=24.10.0->kaggle) (1.1.0)
# Requirement already satisfied: packaging>=22.0 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from black>=24.10.0->kaggle) (25.0)
# Requirement already satisfied: pathspec>=0.9.0 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from black>=24.10.0->kaggle) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from black>=24.10.0->kaggle) (4.5.1)
# Requirement already satisfied: pytokens>=0.3.0 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from black>=24.10.0->kaggle) (0.3.0)
# Requirement already satisfied: colorama in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from click>=8.0.0->black>=24.10.0->kaggle) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.6.0 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from mypy>=1.15.0->kaggle) (4.15.0)
# Requirement already satisfied: librt>=0.6.2 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from mypy>=1.15.0->kaggle) (0.7.4)
# Requirement already satisfied: webencodings in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in f:\workspace\ml\projects\sentiment-analysis\env\lib\site-packages (from requests->kaggle) (2025.11.12)

# %% [markdown]
# ## authenticate using kaggle

# %%
import os
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()
